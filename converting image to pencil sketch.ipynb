# %% [markdown]
# ### Task - Image to pencil sketch

# %% [markdown]
# ### Problem statement:
#      we are trying to convert a color image into a pencil sketch using computer vision in a python programming language.

# %% [markdown]
# ### Import required libraries

# %%
import cv2
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from IPython.display import display

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\anirudh mv\anaconda3\lib\site-packages (4.5.3.56)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\anirudh mv\anaconda3\lib\site-packages (from opencv-python) (1.19.2)

# %% [markdown]
# ### Read image and display

# %%
img = cv2.imread('C:/Users/Anirudh MV/Downloads/goku.jpg',1)
img.shape
# Out:
# (410, 728, 3)

# %%
cv2.imshow('Image',img)  # opens a pop up 
cv2.waitKey(0)  # This will close one particular image opened
cv2.destroyAllWindows()  # Closes all the image pop ups opened all at time

# %%
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(img1))   # Displaying the image
# Out:
# <PIL.Image.Image image mode=RGB size=728x410 at 0x24935684970>

# %% [markdown]
# ### Converting RGB image into Grayscale image

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("New img", gray_image)
cv2.waitKey(0)
# Out:
# -1

# %%
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=728x410 at 0x2493850D160>

# %%
# invert the grayscale image
inverted_image = 255 - gray_image
cv2.imshow("Inverted", inverted_image)
cv2.waitKey()
# Out:
# -1

# %%
display(Image.fromarray(inverted_image))
# Out:
# <PIL.Image.Image image mode=L size=728x410 at 0x2493850D520>

# %% [markdown]
# ##### Negative of the image

# %%
# blur the inverted image
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %% [markdown]
# ### Converting blurred image to a Pencil sketch

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2.imshow("Sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %%
display(Image.fromarray(inverted_blurred))
# Out:
# <PIL.Image.Image image mode=L size=728x410 at 0x2493850D910>

# %%
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=728x410 at 0x2493850D070>

# %% [markdown]
# ### Comparing original image with the pencil sketch

# %%
cv2.imshow("original image", img)
cv2.imshow("pencil sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %%
display(Image.fromarray(img))
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=728x410 at 0x24935684C40>
# <PIL.Image.Image image mode=L size=728x410 at 0x24938671F10>

# %%
res = np.hstack((gray_image,pencil_sketch))
cv2.imshow('im1',res)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
display(Image.fromarray(res))
# Out:
# <PIL.Image.Image image mode=L size=1456x410 at 0x2493850D5E0>
